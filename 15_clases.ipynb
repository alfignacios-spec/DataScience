# %%
class Cuenta:
    def __init__(self,saldo:float):
        self.saldo=saldo

    def depositar(self,monto:float):
        self.saldo+=monto
    
    def retirar(self,monto:float):
        if monto>self.__saldo:
            return 'No hay saldo suficiente.'
        self.__saldo-=monto

    def mostrar_saldo(self,monto:float):
        return self.__saldo
    
    cuenta=Cuenta(1000)
    print(cuenta.mostrar_saldo())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 class Cuenta:
#       2     def __init__(self,saldo:float):
#       3         self.saldo=saldo
#       4
#
# Cell In[11], line 17, in Cuenta()
#      13     def mostrar_saldo(self,monto:float):
#      14         return self.__saldo
#      15
#      16     cuenta=Cuenta(1000)
# ---> 17     print(cuenta.mostrar_saldo())
#
# AttributeError: 'Cuenta' object has no attribute 'mostrar_saldo'

# %%
cuenta=Cuenta(100)
print(cuenta.saldo)
# Out:
# 100

# %%
cuenta.depositar(1000)
print(cuenta.saldo)
# Out:
# 1100

# %%
#Herencia
class Animal
    def __init__(
            self,
            es_domestico:bool,
            num_patas:int,
            nombre:str
    ):
        self.es_domestico=es_domestico
        self.num_patas=num_patas
        self.nombre=nombre
    def comer(self):
        print('Estoy comiendo')

    def beber(self):
        print('Estoy bebiendo')

        pass
