# %%
print("Hola mundo?")
# Out:
# Hola mundo?

# %% [markdown]
# #TIPOS DE VARIABLE

# %%
#variables ejemplos
nombre: str="Alfredo"
apellido: str='Santos'

mi_nombre_completo_es:

print(nombre+' '+apellido)

#variables numericas enteros o int
edad: int=53

#variables numericas decimales
sueldo: float=2300.00


print('mi edad dentro de 5 años sera: ', edad+5)
print('La mital de mi edad actual es: ', edad//2)
print('El resto de mi edad: ', edad % 3)
# Out:
# Alfredo Santos
# mi edad dentro de 5 años sera:  58
# La mital de mi edad actual es:  26
# El resto de mi edad:  2

# %%
nombre=input("Ingresa tu nombre: ")
apellido=input('Ingresa tu apellido')
edad: int=input("Ingresa tu edad: ")
edad_f=edad+5
print("Tu edad en 5 años será: ",edad_f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 nombre=input("Ingresa tu nombre: ")
#       2 apellido=input('Ingresa tu apellido')
#       3 edad: int=input("Ingresa tu edad: ")
# ----> 4 edad_f=edad+5
#       5 print("Tu edad en 5 años será: ",edad_f)
#
# TypeError: can only concatenate str (not "int") to str

# %%
edad=15
print(type(edad))
es_hombre=True
es_mujer=False
print(type(es_mujer))
# Out:
# <class 'int'>
# <class 'bool'>
