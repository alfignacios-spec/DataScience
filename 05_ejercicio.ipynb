# %%
valor=input('Ingrese el monto total de su cuenta: ')
propina=input('Ingrese el porcentaje de propina que dará (en %): ')

valor1=float(valor)
propina1=float(propina)

resultado=valor1*(propina1/100)

#print('El total a pagar es: ',resultado+valor1)

print('¿Desea dividir el pago?')
# Out:
# El total a pagar es:  104.5
