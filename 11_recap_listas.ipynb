# %%
lista_numeros=[
    1, 3, 5, 7, 9
    ]

# %%
len(lista_numeros)
# Out:
# 5

# %%
lista_numeros.insert(0,10)
print(lista_numeros)
# Out:
# [10, 10, 1, 3, 5, 7, 9]

# %%
lista_numeros.insert(0,'fruta')
print(lista_numeros)
# Out:
# ['fruta', 'fruta', 'fruta', 10, 10, 1, 3, 5, 7, 9]

# %%
lista_numeros.append(13)
lista_numeros.append(15)
print(lista_numeros)
# Out:
# ['fruta', 'fruta', 'fruta', 10, 10, 1, 3, 5, 7, 9, 13, 13, 15]

# %%
lista_frutas=['manzana','platano','mango']
lista_numeros.append(lista_frutas)
print(lista_numeros)
# Out:
# ['fruta', 'fruta', 'fruta', 10, 10, 1, 3, 5, 7, 9, 13, 13, 15, ['manzana', 'platano', 'mango']]

# %%
import random
n_random=[]

for _ in range(10):
    n_random.append(random.randint(0,20))
print(n_random)
# Out:
# [7, 16, 19, 2, 4, 10, 10, 9, 7, 2]

# %%
n_random.sort()
print(n_random)
# Out:
# [2, 2, 4, 7, 7, 9, 10, 10, 16, 19]

# %%
lista_letras=['x','a','f','g']
lista_letras.sort()
print(lista_letras)
# Out:
# ['a', 'f', 'g', 'x']

# %%
#pop elimina el ultimo elemento de lista
lista_letras.pop()
print(lista_letras)
# Out:
# ['a', 'f', 'g']

# %%
lista_letras=['x','a','f','g']
lista_letras.reverse()
print(lista_letras)
# Out:
# ['g', 'f', 'a', 'x']

# %%
lista_letras1=['x','a','f','g']
lista_letras2=['t','h','w','p']

for letra in lista_letras2:
    lista_letras1.append(letra)

print(lista_letras1)
# Out:
# ['x', 'a', 'f', 'g', 't', 'h', 'w', 'p']

# %%
lista_letras1=['x','a','f','g']
lista_letras2=['t','h','w','p']
lista_letras1.extend(lista_letras2)
print(lista_letras1)
# Out:
# ['x', 'a', 'f', 'g', 't', 'h', 'w', 'p']

# %%
lista_letras1=['x','a','f','g']
lista_letras2=['t','h','w','p']
nueva_lista=lista_letras2+lista_letras1
print(nueva_lista)
# Out:
# ['t', 'h', 'w', 'p', 'x', 'a', 'f', 'g']

# %%
import random
n_random=[]

for _ in range(10):
    n_random.append(random.randint(0,20))
print(n_random)

n_random.count(4)
# Out:
# [18, 12, 1, 16, 7, 8, 12, 4, 17, 3]
# 1

# %%
lista_letras1=['x','a','f','g']
lista_letras2=['t','h','w','p']
nueva_lista=lista_letras2+lista_letras1
print(nueva_lista)
nueva_lista.count('f')
# Out:
# ['t', 'h', 'w', 'p', 'x', 'a', 'f', 'g']
# 1
