# %%
lista=list(range(9))
for item in lista:
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
lista.append(8)
print(lista)

lista.append([1,4,7])
print(lista)

lista.insert(0,'Juancho')
print(lista)

lista.insert(-1,'Nacho')
print(lista)

lista.remove(6)
print(lista)
# Out:
# ['Juancho', 0, 1, 2, 3, 4, 5, 7, 8, 8, 'Nacho', [1, 4, 7], 8]
# ['Juancho', 0, 1, 2, 3, 4, 5, 7, 8, 8, 'Nacho', [1, 4, 7], 8, [1, 4, 7]]
# ['Juancho', 'Juancho', 0, 1, 2, 3, 4, 5, 7, 8, 8, 'Nacho', [1, 4, 7], 8, [1, 4, 7]]
# ['Juancho', 'Juancho', 0, 1, 2, 3, 4, 5, 7, 8, 8, 'Nacho', [1, 4, 7], 8, 'Nacho', [1, 4, 7]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 13
#       9
#      10 lista.insert(-1,'Nacho')
#      11 print(lista)
#      12
# ---> 13 lista.remove(6)
#      14 print(lista)
#      15
#      16 lista.pop()
#
# ValueError: list.remove(x): x not in list
