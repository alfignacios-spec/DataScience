# %%
lista=list(range(9))
for item in lista:
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
lista.append(8)
print(lista)

lista.append([1,4,7])
print(lista)

lista.insert(0,'Juancho')
print(lista)

lista.insert(-1,'Nacho')
print(lista)

lista.remove(6)
print(lista)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8, 8]
# [0, 1, 2, 3, 4, 5, 6, 7, 8, 8, [1, 4, 7]]
# ['Juancho', 0, 1, 2, 3, 4, 5, 6, 7, 8, 8, [1, 4, 7]]
# ['Juancho', 0, 1, 2, 3, 4, 5, 6, 7, 8, 8, 'Nacho', [1, 4, 7]]
# ['Juancho', 0, 1, 2, 3, 4, 5, 7, 8, 8, 'Nacho', [1, 4, 7]]
