-- %%
CREATE TABLE IF NOT EXISTS categorias (
        id INT NOT NULL,
        nombre STRING NOT NULL
    );
    CREATE TABLE IF NOT EXISTS productos (
        id INT NOT NULL,
        nombre STRING NOT NULL,
        precio NUMERIC NOT NULL,
        stock INT,
        categoria_id INT NOT NULL
    );
    CREATE TABLE IF NOT EXISTS detalle_pedidos(
        pedido_id INT NOT NULL,
        producto_id INT NOT NULL,
        cantidad INT,
        precio_unit NUMERIC
    );
    CREATE TABLE IF NOT EXISTS pedidos(
        id INT NOT NULL,
        cliente_id INT NOT NULL,
        fecha DATE,
        total NUMERIC
    );
    CREATE TABLE IF NOT EXISTS clientes(
        id INT NOT NULL,
        nombre STRING NOT NULL,
        email STRING,
        pais STRING,
        telefono STRING
    )

-- %%
ALTER TABLE productos ALTER COLUMN categoria_id DROP NOT NULL;

-- %%
INSERT INTO clientes (id, nombre, email, pais, telefono) VALUES
  (1,  'Ana López',       'ana.lopez@gmail.com',      'ES', '600111222'),
  (2,  'Luis Paz',        'luis.paz@mail.com',        'MX', NULL),
  (3,  'Marta Ruiz',      'marta.ruiz@gmail.com',     'ES', '600333444'),
  (4,  'Carlos Gómez',    'carlos.gomez@empresa.com', 'AR', '1155667788'),
  (5,  'Lucía Fernández', 'lucia.fdez@mail.com',      'ES', NULL),
  (6,  'Diego Torres',    'diego.torres@mail.com',    'MX', '5544332211'),
  (7,  'Sofía Herrera',   'sofia.herrera@gmail.com',  'CO', '3001234567'),
  (8,  'Pedro Sánchez',   'pedro.sanchez@mail.com',   'CL', '987654321'),
  (9,  'Elena Navarro',   'elena.navarro@mail.com',   'ES', '600555666'),  -- sin pedidos (LEFT JOIN)
  (10, 'Javier Molina',   'javier.molina@mail.com',   'AR', NULL);         -- sin pedidos (LEFT JOIN)

INSERT INTO productos (id, nombre, precio, stock, categoria_id) VALUES
  (1,  'Portátil 14 pulgadas',  899.00, 15,  1),
  (2,  'Auriculares Bluetooth',  59.90, 80,  1),
  (3,  'Smartphone X',          649.00, 25,  1),
  (4,  'Camiseta básica',        12.50, 200, 2),
  (5,  'Vaqueros clásicos',      39.95, 120, 2),
  (6,  'Chaqueta de invierno',   89.00, 40,  2),
  (7,  'Cafetera italiana',      24.90, 60,  3),
  (8,  'Lámpara de escritorio',  18.50, 75,  3),
  (9,  'Bicicleta urbana',      320.00, 10,  4),
  (10, 'Balón de fútbol',        15.99, 150, 4),
  (11, 'Puzzle 1000 piezas',      9.99, 90,  5),
  (12, 'Tarjeta regalo',         25.00, 999, NULL);  -- sin categoría a propósito

INSERT INTO pedidos (id, cliente_id, fecha, total) VALUES
  (1,  1, DATE'2019-05-12', 958.90),
  (2,  2, DATE'2020-03-08',  64.95),
  (3,  1, DATE'2020-11-30',  24.90),
  (4,  3, DATE'2021-02-14', 649.00),
  (5,  4, DATE'2021-07-01',  57.96),
  (6,  2, DATE'2022-01-20', 101.50),
  (7,  5, DATE'2022-06-05', 320.00),
  (8,  6, DATE'2022-09-17',  61.90),
  (9,  3, DATE'2023-03-03',  50.00),
  (10, 7, DATE'2023-08-22',  84.90),
  (11, 1, DATE'2024-04-10', 708.90),
  (12, 8, DATE'2024-10-05',  41.97),
  (13, 5, DATE'2025-01-15',  52.45),
  (14, 6, DATE'2025-05-30', 899.00),
  (15, 7, DATE'2025-12-02',  68.30),
  (16, 4, DATE'2026-03-18', 335.99);

INSERT INTO detalle_pedidos (pedido_id, producto_id, cantidad, precio_unit) VALUES
  (1,  1,  1, 899.00),
  (1,  2,  1,  59.90),
  (2,  4,  2,  12.50),
  (2,  5,  1,  39.95),
  (3,  7,  1,  24.90),
  (4,  3,  1, 649.00),
  (5,  10, 3,  15.99),
  (5,  11, 1,   9.99),
  (6,  6,  1,  89.00),
  (6,  4,  1,  12.50),
  (7,  9,  1, 320.00),
  (8,  8,  2,  18.50),
  (8,  7,  1,  24.90),
  (9,  4,  4,  12.50),
  (10, 2,  1,  59.90),
  (10, 12, 1,  25.00),
  (11, 3,  1, 649.00),
  (11, 2,  1,  59.90),
  (12, 11, 1,   9.99),
  (12, 10, 2,  15.99),
  (13, 5,  1,  39.95),
  (13, 4,  1,  12.50),
  (14, 1,  1, 899.00),
  (15, 7,  2,  24.90),
  (15, 8,  1,  18.50),
  (16, 9,  1, 320.00),
  (16, 10, 1,  15.99);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>27</td><td>27</td></tr></tbody></table></div>

-- %%
select*
from productos;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>nombre</th><th>precio</th><th>stock</th><th>categoria_id</th></tr></thead><tbody><tr><td>1</td><td>Portátil 14 pulgadas</td><td>899</td><td>15</td><td>1</td></tr><tr><td>2</td><td>Auriculares Bluetooth</td><td>60</td><td>80</td><td>1</td></tr><tr><td>3</td><td>Smartphone X</td><td>649</td><td>25</td><td>1</td></tr><tr><td>4</td><td>Camiseta básica</td><td>13</td><td>200</td><td>2</td></tr><tr><td>5</td><td>Vaqueros clásicos</td><td>40</td><td>120</td><td>2</td></tr><tr><td>6</td><td>Chaqueta de invierno</td><td>89</td><td>40</td><td>2</td></tr><tr><td>7</td><td>Cafetera italiana</td><td>25</td><td>60</td><td>3</td></tr><tr><td>8</td><td>Lámpara de escritorio</td><td>19</td><td>75</td><td>3</td></tr><tr><td>9</td><td>Bicicleta urbana</td><td>320</td><td>10</td><td>4</td></tr><tr><td>10</td><td>Balón de fútbol</td><td>16</td><td>150</td><td>4</td></tr><tr><td>11</td><td>Puzzle 1000 piezas</td><td>10</td><td>90</td><td>5</td></tr><tr><td>12</td><td>Tarjeta regalo</td><td>25</td><td>999</td><td>null</td></tr></tbody></table></div>

-- %%
-- Ejercicio 1
-- select
--     min(precio) as precio_minimo,
--     max(precio) as precio_maximo
-- from productos

SELECT *
FROM productos
ORDER BY precio DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>nombre</th><th>precio</th><th>stock</th><th>categoria_id</th></tr></thead><tbody><tr><td>1</td><td>Portátil 14 pulgadas</td><td>899</td><td>15</td><td>1</td></tr><tr><td>3</td><td>Smartphone X</td><td>649</td><td>25</td><td>1</td></tr><tr><td>9</td><td>Bicicleta urbana</td><td>320</td><td>10</td><td>4</td></tr><tr><td>6</td><td>Chaqueta de invierno</td><td>89</td><td>40</td><td>2</td></tr><tr><td>2</td><td>Auriculares Bluetooth</td><td>60</td><td>80</td><td>1</td></tr><tr><td>5</td><td>Vaqueros clásicos</td><td>40</td><td>120</td><td>2</td></tr><tr><td>7</td><td>Cafetera italiana</td><td>25</td><td>60</td><td>3</td></tr><tr><td>12</td><td>Tarjeta regalo</td><td>25</td><td>999</td><td>null</td></tr><tr><td>8</td><td>Lámpara de escritorio</td><td>19</td><td>75</td><td>3</td></tr><tr><td>10</td><td>Balón de fútbol</td><td>16</td><td>150</td><td>4</td></tr><tr><td>4</td><td>Camiseta básica</td><td>13</td><td>200</td><td>2</td></tr><tr><td>11</td><td>Puzzle 1000 piezas</td><td>10</td><td>90</td><td>5</td></tr></tbody></table></div>

-- %%
select* 
from clientes
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>nombre</th><th>email</th><th>pais</th><th>telefono</th></tr></thead><tbody><tr><td>1</td><td>Ana López</td><td>ana.lopez@gmail.com</td><td>ES</td><td>600111222</td></tr><tr><td>2</td><td>Luis Paz</td><td>luis.paz@mail.com</td><td>MX</td><td>null</td></tr><tr><td>3</td><td>Marta Ruiz</td><td>marta.ruiz@gmail.com</td><td>ES</td><td>600333444</td></tr><tr><td>4</td><td>Carlos Gómez</td><td>carlos.gomez@empresa.com</td><td>AR</td><td>1155667788</td></tr><tr><td>5</td><td>Lucía Fernández</td><td>lucia.fdez@mail.com</td><td>ES</td><td>null</td></tr><tr><td>6</td><td>Diego Torres</td><td>diego.torres@mail.com</td><td>MX</td><td>5544332211</td></tr><tr><td>7</td><td>Sofía Herrera</td><td>sofia.herrera@gmail.com</td><td>CO</td><td>3001234567</td></tr><tr><td>8</td><td>Pedro Sánchez</td><td>pedro.sanchez@mail.com</td><td>CL</td><td>987654321</td></tr><tr><td>9</td><td>Elena Navarro</td><td>elena.navarro@mail.com</td><td>ES</td><td>600555666</td></tr><tr><td>10</td><td>Javier Molina</td><td>javier.molina@mail.com</td><td>AR</td><td>null</td></tr><tr><td>1</td><td>Ana López</td><td>ana.lopez@gmail.com</td><td>ES</td><td>600111222</td></tr><tr><td>2</td><td>Luis Paz</td><td>luis.paz@mail.com</td><td>MX</td><td>null</td></tr><tr><td>3</td><td>Marta Ruiz</td><td>marta.ruiz@gmail.com</td><td>ES</td><td>600333444</td></tr><tr><td>4</td><td>Carlos Gómez</td><td>carlos.gomez@empresa.com</td><td>AR</td><td>1155667788</td></tr><tr><td>5</td><td>Lucía Fernández</td><td>lucia.fdez@mail.com</td><td>ES</td><td>null</td></tr><tr><td>6</td><td>Diego Torres</td><td>diego.torres@mail.com</td><td>MX</td><td>5544332211</td></tr><tr><td>7</td><td>Sofía Herrera</td><td>sofia.herrera@gmail.com</td><td>CO</td><td>3001234567</td></tr><tr><td>8</td><td>Pedro Sánchez</td><td>pedro.sanchez@mail.com</td><td>CL</td><td>987654321</td></tr><tr><td>9</td><td>Elena Navarro</td><td>elena.navarro@mail.com</td><td>ES</td><td>600555666</td></tr><tr><td>10</td><td>Javier Molina</td><td>javier.molina@mail.com</td><td>AR</td><td>null</td></tr><tr><td>1</td><td>Ana López</td><td>ana.lopez@gmail.com</td><td>ES</td><td>600111222</td></tr><tr><td>2</td><td>Luis Paz</td><td>luis.paz@mail.com</td><td>MX</td><td>null</td></tr><tr><td>3</td><td>Marta Ruiz</td><td>marta.ruiz@gmail.com</td><td>ES</td><td>600333444</td></tr><tr><td>4</td><td>Carlos Gómez</td><td>carlos.gomez@empresa.com</td><td>AR</td><td>1155667788</td></tr><tr><td>5</td><td>Lucía Fernández</td><td>lucia.fdez@mail.com</td><td>ES</td><td>null</td></tr><tr><td>6</td><td>Diego Torres</td><td>diego.torres@mail.com</td><td>MX</td><td>5544332211</td></tr><tr><td>7</td><td>Sofía Herrera</td><td>sofia.herrera@gmail.com</td><td>CO</td><td>3001234567</td></tr><tr><td>8</td><td>Pedro Sánchez</td><td>pedro.sanchez@mail.com</td><td>CL</td><td>987654321</td></tr><tr><td>9</td><td>Elena Navarro</td><td>elena.navarro@mail.com</td><td>ES</td><td>600555666</td></tr><tr><td>10</td><td>Javier Molina</td><td>javier.molina@mail.com</td><td>AR</td><td>null</td></tr><tr><td>1</td><td>Ana López</td><td>ana.lopez@gmail.com</td><td>ES</td><td>600111222</td></tr><tr><td>2</td><td>Luis Paz</td><td>luis.paz@mail.com</td><td>MX</td><td>null</td></tr><tr><td>3</td><td>Marta Ruiz</td><td>marta.ruiz@gmail.com</td><td>ES</td><td>600333444</td></tr><tr><td>4</td><td>Carlos Gómez</td><td>carlos.gomez@empresa.com</td><td>AR</td><td>1155667788</td></tr><tr><td>5</td><td>Lucía Fernández</td><td>lucia.fdez@mail.com</td><td>ES</td><td>null</td></tr><tr><td>6</td><td>Diego Torres</td><td>diego.torres@mail.com</td><td>MX</td><td>5544332211</td></tr><tr><td>7</td><td>Sofía Herrera</td><td>sofia.herrera@gmail.com</td><td>CO</td><td>3001234567</td></tr><tr><td>8</td><td>Pedro Sánchez</td><td>pedro.sanchez@mail.com</td><td>CL</td><td>987654321</td></tr><tr><td>9</td><td>Elena Navarro</td><td>elena.navarro@mail.com</td><td>ES</td><td>6005556 ...

-- %%
-- DROP TABLE IF EXISTS clientes

-- %%
CREATE TABLE IF NOT EXISTS clientes(
        id INT NOT NULL,
        nombre STRING NOT NULL,
        email STRING,
        pais STRING,
        telefono STRING
    )

-- %%
select* 
from clientes
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>nombre</th><th>email</th><th>pais</th><th>telefono</th></tr></thead><tbody><tr><td>1</td><td>Ana López</td><td>ana.lopez@gmail.com</td><td>ES</td><td>600111222</td></tr><tr><td>2</td><td>Luis Paz</td><td>luis.paz@mail.com</td><td>MX</td><td>null</td></tr><tr><td>3</td><td>Marta Ruiz</td><td>marta.ruiz@gmail.com</td><td>ES</td><td>600333444</td></tr><tr><td>4</td><td>Carlos Gómez</td><td>carlos.gomez@empresa.com</td><td>AR</td><td>1155667788</td></tr><tr><td>5</td><td>Lucía Fernández</td><td>lucia.fdez@mail.com</td><td>ES</td><td>null</td></tr><tr><td>6</td><td>Diego Torres</td><td>diego.torres@mail.com</td><td>MX</td><td>5544332211</td></tr><tr><td>7</td><td>Sofía Herrera</td><td>sofia.herrera@gmail.com</td><td>CO</td><td>3001234567</td></tr><tr><td>8</td><td>Pedro Sánchez</td><td>pedro.sanchez@mail.com</td><td>CL</td><td>987654321</td></tr><tr><td>9</td><td>Elena Navarro</td><td>elena.navarro@mail.com</td><td>ES</td><td>600555666</td></tr><tr><td>10</td><td>Javier Molina</td><td>javier.molina@mail.com</td><td>AR</td><td>null</td></tr></tbody></table></div>

-- %%
INSERT INTO clientes (id, nombre, email, pais, telefono) VALUES
  (1,  'Ana López',       'ana.lopez@gmail.com',      'ES', '600111222'),
  (2,  'Luis Paz',        'luis.paz@mail.com',        'MX', NULL),
  (3,  'Marta Ruiz',      'marta.ruiz@gmail.com',     'ES', '600333444'),
  (4,  'Carlos Gómez',    'carlos.gomez@empresa.com', 'AR', '1155667788'),
  (5,  'Lucía Fernández', 'lucia.fdez@mail.com',      'ES', NULL),
  (6,  'Diego Torres',    'diego.torres@mail.com',    'MX', '5544332211'),
  (7,  'Sofía Herrera',   'sofia.herrera@gmail.com',  'CO', '3001234567'),
  (8,  'Pedro Sánchez',   'pedro.sanchez@mail.com',   'CL', '987654321'),
  (9,  'Elena Navarro',   'elena.navarro@mail.com',   'ES', '600555666'),  -- sin pedidos (LEFT JOIN)
  (10, 'Javier Molina',   'javier.molina@mail.com',   'AR', NULL);         -- sin pedidos (LEFT JOIN)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

-- %%
-- select pais
-- from clientes
-- where pais like 'MX'
-- or pais like 'ES'



-- select pais
-- from clientes
-- where pais like 'MX'
-- or pais like 'ES'
-- group by clientes.pais
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pais</th></tr></thead><tbody><tr><td>ES</td></tr><tr><td>MX</td></tr><tr><td>ES</td></tr><tr><td>ES</td></tr><tr><td>MX</td></tr><tr><td>ES</td></tr></tbody></table></div>

-- %%
--Ejercicio 2
SELECT nombre, pais
FROM clientes
WHERE pais IN ('MX', 'ES')
     and nombre like 'M%'
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre</th><th>pais</th></tr></thead><tbody><tr><td>Marta Ruiz</td><td>ES</td></tr></tbody></table></div>

-- %%
--Ejercicio 3
SELECT id, nombre, precio, stock
FROM productos

WHERE precio BETWEEN 20 and 60
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>nombre</th><th>precio</th><th>stock</th></tr></thead><tbody><tr><td>2</td><td>Auriculares Bluetooth</td><td>60</td><td>80</td></tr><tr><td>5</td><td>Vaqueros clásicos</td><td>40</td><td>120</td></tr><tr><td>7</td><td>Cafetera italiana</td><td>25</td><td>60</td></tr><tr><td>12</td><td>Tarjeta regalo</td><td>25</td><td>999</td></tr></tbody></table></div>

-- %%
--Ejercicio 4
SELECT nombre,COALESCE(telefono, 'Sin dato') AS telefono_usuario
FROM clientes
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre</th><th>telefono_usuario</th></tr></thead><tbody><tr><td>Ana López</td><td>600111222</td></tr><tr><td>Luis Paz</td><td>Sin dato</td></tr><tr><td>Marta Ruiz</td><td>600333444</td></tr><tr><td>Carlos Gómez</td><td>1155667788</td></tr><tr><td>Lucía Fernández</td><td>Sin dato</td></tr><tr><td>Diego Torres</td><td>5544332211</td></tr><tr><td>Sofía Herrera</td><td>3001234567</td></tr><tr><td>Pedro Sánchez</td><td>987654321</td></tr><tr><td>Elena Navarro</td><td>600555666</td></tr><tr><td>Javier Molina</td><td>Sin dato</td></tr></tbody></table></div>

-- %%
--Ejercicio 5
SELECT nombre,precio, 
precio*1.21 AS precio_iva
FROM productos
ORDER BY precio_iva DESC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre</th><th>precio</th><th>precio_iva</th></tr></thead><tbody><tr><td>Portátil 14 pulgadas</td><td>899</td><td>1087.79</td></tr><tr><td>Smartphone X</td><td>649</td><td>785.29</td></tr><tr><td>Bicicleta urbana</td><td>320</td><td>387.20</td></tr><tr><td>Chaqueta de invierno</td><td>89</td><td>107.69</td></tr><tr><td>Auriculares Bluetooth</td><td>60</td><td>72.60</td></tr><tr><td>Vaqueros clásicos</td><td>40</td><td>48.40</td></tr><tr><td>Cafetera italiana</td><td>25</td><td>30.25</td></tr><tr><td>Tarjeta regalo</td><td>25</td><td>30.25</td></tr><tr><td>Lámpara de escritorio</td><td>19</td><td>22.99</td></tr><tr><td>Balón de fútbol</td><td>16</td><td>19.36</td></tr></tbody></table></div>

-- %%
--Ejercicio 6
SELECT nombre, precio,
       CASE
           WHEN precio>650 THEN 'Producto caro'
           WHEN precio BETWEEN 200 AND 650 THEN 'Producto medio'
           WHEN precio<200 THEN 'Producto barato'
       END AS valoracion_costo
FROM Productos;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre</th><th>precio</th><th>valoracion_costo</th></tr></thead><tbody><tr><td>Portátil 14 pulgadas</td><td>899</td><td>Producto caro</td></tr><tr><td>Auriculares Bluetooth</td><td>60</td><td>Producto barato</td></tr><tr><td>Smartphone X</td><td>649</td><td>Producto medio</td></tr><tr><td>Camiseta básica</td><td>13</td><td>Producto barato</td></tr><tr><td>Vaqueros clásicos</td><td>40</td><td>Producto barato</td></tr><tr><td>Chaqueta de invierno</td><td>89</td><td>Producto barato</td></tr><tr><td>Cafetera italiana</td><td>25</td><td>Producto barato</td></tr><tr><td>Lámpara de escritorio</td><td>19</td><td>Producto barato</td></tr><tr><td>Bicicleta urbana</td><td>320</td><td>Producto medio</td></tr><tr><td>Balón de fútbol</td><td>16</td><td>Producto barato</td></tr><tr><td>Puzzle 1000 piezas</td><td>10</td><td>Producto barato</td></tr><tr><td>Tarjeta regalo</td><td>25</td><td>Producto barato</td></tr></tbody></table></div>

-- %%
--Ejercicio 7
select distinct pais as paises_unicos
-- count(distinct pais)
from clientes;

select count(distinct pais) as total_paises_unicos
from clientes
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_paises_unicos</th></tr></thead><tbody><tr><td>5</td></tr></tbody></table></div>
