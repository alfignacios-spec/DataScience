# %%
#FUnciones u operadores string
long de mi cadena=len
convert a mayus=(upper)
convert a minus=(lower)
reemplazar un valor del txt=(replace)
'texto'->(strip)->'texto'
'texto1.texto2.texto3'->(split,',')--[texto1,texto2,texto3]

# %%
nombre='Alfredo'
print(len(nombre))
# Out:
# 7

# %%
#replace lit reemplaza
print(nombre.replace("A";"E"))
# Out:
#   Cell In[5], line 2
#     print(nombre.replace("A";"E"))
#                             ^
# SyntaxError: invalid syntax
